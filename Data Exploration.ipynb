# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Data collection and Data exploration

# %%
import pandas as pd
import numpy as np
dataset_for_exploration=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/NIA_MINIPROJECT/titles.csv')

# %% [markdown]
# Checking dimensions of the dataset

# %%
print(dataset_for_exploration.shape)
# Out:
# (5850, 15)

# %% [markdown]
# Checking the head of data (First 5 records)

# %%
print(dataset_for_exploration.head(5))
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# ...

# %% [markdown]
# Checking different columns and variable types

# %%
print(dataset_for_exploration.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5850 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5850 non-null   object
#  3   description           5832 non-null   object
#  4   release_year          5850 non-null   int64
#  5   age_certification     3231 non-null   object
#  6   runtime               5850 non-null   int64
#  7   genres                5850 non-null   object
#  8   production_countries  5850 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               5447 non-null   object
#  11  imdb_score            5368 non-null   float64
#  12  imdb_votes            5352 non-null   float64
#  13  tmdb_popularity       5759 non-null   float64
#  14  tmdb_score            5539 non-null   float64
# ...

# %% [markdown]
# Statistical details for all numerical columns

# %%
print(dataset_for_exploration.describe())
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   5850.000000  5850.000000  2106.000000  5368.000000  5.352000e+03
# mean    2016.417094    76.888889     2.162868     6.510861  2.343938e+04
# std        6.937726    39.002509     2.689041     1.163826  9.582047e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2016.000000    44.000000     1.000000     5.800000  5.167500e+02
# 50%     2018.000000    83.000000     1.000000     6.600000  2.233500e+03
# 75%     2020.000000   104.000000     2.000000     7.300000  9.494000e+03
# max     2022.000000   240.000000    42.000000     9.600000  2.294231e+06
#
#        tmdb_popularity   tmdb_score
# count      5759.000000  5539.000000
# mean         22.637925     6.829175
# std          81.680263     1.170391
# min           0.009442     0.500000
# 25%           2.728500     6.100000
# 50%           6.821000     6.900000
# 75%          16.590000     7.537500
# ...

# %% [markdown]
# Checking for null values in columns

# %%
print(dataset_for_exploration.isnull().sum())
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2619
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3744
# imdb_id                  403
# imdb_score               482
# imdb_votes               498
# tmdb_popularity           91
# tmdb_score               311
# dtype: int64

# %% [markdown]
# Checking for uniques values in categorical variable columns

# %%
for col in dataset_for_exploration.select_dtypes(include=['object']):
    print(f"Column: {col}")
    print(dataset_for_exploration[col].unique())
# Out:
# Column: id
# ['ts300399' 'tm84618' 'tm154986' ... 'tm1059008' 'tm1035612' 'ts271048']
# Column: title
# ['Five Came Back: The Reference Films' 'Taxi Driver' 'Deliverance' ...
#  'Lokillo' 'Dad Stop Embarrassing Me - The Afterparty'
#  'Mighty Little Bheem: Kite Festival']
# Column: type
# ['SHOW' 'MOVIE']
# Column: description
# ['This collection includes 12 World War II-era propaganda films — many of which are graphic and offensive — discussed in the docuseries "Five Came Back."'
#  'A mentally unstable Vietnam War veteran works as a night-time taxi driver in New York City where the perceived decadence and sleaze feed his urge for violent action.'
#  "Intent on seeing the Cahulawassee River before it's turned into one huge lake, outdoor fanatic Lewis Medlock takes his friends on a river-rafting trip they'll never forget into the dangerous American back-country."
#  ...
# ...

# %% [markdown]
# Numerical variable list

# %%
numerical_columns = dataset_for_exploration.select_dtypes(include=['number']).columns
print(numerical_columns)
# Out:
# Index(['release_year', 'runtime', 'seasons', 'imdb_score', 'imdb_votes',
#        'tmdb_popularity', 'tmdb_score'],
#       dtype='object')

# %% [markdown]
# Categorical variable list

# %%
categorical_columns = dataset_for_exploration.select_dtypes(include=['object']).columns
print(categorical_columns)
# Out:
# Index(['id', 'title', 'type', 'description', 'age_certification', 'genres',
#        'production_countries', 'imdb_id'],
#       dtype='object')
